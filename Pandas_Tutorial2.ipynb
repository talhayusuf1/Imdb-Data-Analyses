# %%
import pandas as pd

# %%
df = pd.read_csv("imdb_top_1000.csv")

# %%
df.head(4)
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
#
#                Director           Star1           Star2          Star3  \
# ...

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# ...

# %%
df_new = df.drop(["Overview","Meta_score"],axis = 1) # axis = 1 column drop,axis=0 row drop
df_new.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating              Director           Star1  \
# 0                 Drama          9.3        Frank Darabont     Tim Robbins
# 1          Crime, Drama          9.2  Francis Ford Coppola   Marlon Brando
# 2  Action, Crime, Drama          9.0     Christopher Nolan  Christian Bale
# 3          Crime, Drama          9.0  Francis Ford Coppola       Al Pacino
# 4          Crime, Drama          9.0          Sidney Lumet     Henry Fonda
#
#             Star2          Star3           Star4  No_of_Votes        Gross
# ...

# %%
df_new2 = df.drop([1])
df_new2.head()
# Out:
#                                     Series_Title Released_Year Certificate  \
# 0                       The Shawshank Redemption          1994           A
# 2                                The Dark Knight          2008          UA
# 3                         The Godfather: Part II          1974           A
# 4                                   12 Angry Men          1957           U
# 5  The Lord of the Rings: The Return of the King          2003           U
#
#    Runtime                     Genre  IMDB_Rating  \
# 0  142 min                     Drama          9.3
# 2  152 min      Action, Crime, Drama          9.0
# 3  202 min              Crime, Drama          9.0
# 4   96 min              Crime, Drama          9.0
# 5  201 min  Action, Adventure, Drama          8.9
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# ...

# %% [markdown]
# FILTERED

# %%
df_filtered = df[df["IMDB_Rating"]>=8.9]
df_filtered
# Out:
#                                     Series_Title Released_Year Certificate  \
# 0                       The Shawshank Redemption          1994           A
# 1                                  The Godfather          1972           A
# 2                                The Dark Knight          2008          UA
# 3                         The Godfather: Part II          1974           A
# 4                                   12 Angry Men          1957           U
# 5  The Lord of the Rings: The Return of the King          2003           U
# 6                                   Pulp Fiction          1994           A
# 7                               Schindler's List          1993           A
#
#    Runtime                      Genre  IMDB_Rating  \
# 0  142 min                      Drama          9.3
# 1  175 min               Crime, Drama          9.2
# 2  152 min       Action, Crime, Drama          9.0
# 3  202 min               Crime, Drama          9.0
# ...

# %%
df_filtered = df.query("IMDB_Rating >= 9")
df_filtered
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# ...

# %%
f = lambda x: (x["Runtime"].split())[0]
df["RuntimeNew"] = df.apply(f,axis=1)

# %%
df.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# ...

# %%
df = df.drop(["RuntimeNew2"],axis = 1)

# %%
df.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# ...

# %%
df["RuntimeNew"] = df["RuntimeNew"].astype("int")

df_filtered = df.query("RuntimeNew >= 200")
df_filtered
# Out:
#                                       Series_Title Released_Year Certificate  \
# 3                           The Godfather: Part II          1974           A
# 5    The Lord of the Rings: The Return of the King          2003           U
# 31                            Shichinin no samurai          1954           U
# 71                     Once Upon a Time in America          1984           A
# 116                             Lawrence of Arabia          1962           U
# 140                             Gangs of Wasseypur          2012           A
# 156                         Swades: We, the People          2004           U
# 177                                         Sholay          1975           U
# 247              Lagaan: Once Upon a Time in India          2001           U
# 290                                  Andrei Rublev          1966           R
# 300                                        Ben-Hur          1959           U
# ...
